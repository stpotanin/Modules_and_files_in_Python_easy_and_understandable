# %% [markdown]
# https://stepik.org/lesson/1732669/step/7

# %%
# !pip freeze > requirements.txt

with open ('requirements.txt', 'r') as f:
    lines = f.readlines()
    print(len(lines))
# Out:
# 666
