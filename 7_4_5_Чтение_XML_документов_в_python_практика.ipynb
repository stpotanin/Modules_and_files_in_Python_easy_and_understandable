# %% [markdown]
# https://stepik.org/lesson/2231489/step/5
#
# [GitHub Repository](https://github.com/artemegorof/modules_and_files/blob/main/module_07/lesson_04/step_05/tests)
#
# # Универсальный обход дерева

# %%
import xml.etree.ElementTree as ET

def count_tags(filename):
    root = ET.parse(filename).getroot()
    return {elem.tag: len(list(root.iter(elem.tag))) for elem in root.iter()}

# %%
# @title Краткая проверка
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_07/lesson_04/step_05/test_1.xml'

print(count_tags("test_1.xml"))
# {'root': 1, 'item': 2, 'name': 2}
# Out:
# {'root': 1, 'item': 2, 'name': 2}
