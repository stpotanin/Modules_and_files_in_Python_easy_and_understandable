# %% [markdown]
# https://stepik.org/lesson/1887961/step/14

# %%
def print_file_content(text_file):
    with open(text_file, 'r') as f:
        print(f.read())

print_file_content('mytext.txt')
# Out:
# 123
# 456
