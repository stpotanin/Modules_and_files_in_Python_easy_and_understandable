# %% [markdown]
# https://stepik.org/lesson/1612298/step/11

# %%
# @title Вариант с .lower()
def count_unique_words(file):
    with open(file) as f: return len(set(w for line in f for w in line.lower().split()))

# %%
# @title Вариант с casefold()
# def count_unique_words(file):
#     with open(file) as f: return len(set(w.casefold() for line in f for w in line.split()))

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_11/test1.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_11/test2.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_11/test3.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_11/test4.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_11/test5.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_11/test6.txt'

# %%
print(count_unique_words('test1.txt')) # 4
print(count_unique_words('test2.txt')) # 20
print(count_unique_words('test3.txt')) # 4
print(count_unique_words('test4.txt')) # 1
print(count_unique_words('test5.txt')) # 5
print(count_unique_words('test6.txt')) # 26
# Out:
# 4
# 20
# 4
# 1
# 5
# 26
