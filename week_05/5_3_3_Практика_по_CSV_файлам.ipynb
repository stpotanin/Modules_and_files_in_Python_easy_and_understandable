# %% [markdown]
# https://stepik.org/lesson/2018079/step/3
#
# [GitHub Repository](https://github.com/artemegorof/modules_and_files/blob/main/module_05/lesson_03/step_03/tests)
#
# # Список названий книг

# %%
import csv

def print_book_titles(filename):
    with open(filename, encoding='utf-8') as f:
        [print(x[1]) for x in list(csv.reader(f))[1:]]

# %%
# @title Короткая проверка
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_05/lesson_03/step_03/library_books.csv'

print_book_titles("library_books.csv")

# вызов должен распечатать на экран следующее:

# 1984
# Мастер и Маргарита
# Три товарища
# Преступление и наказание
# Out:
# 1984
# Мастер и Маргарита
# Три товарища
# Преступление и наказание
