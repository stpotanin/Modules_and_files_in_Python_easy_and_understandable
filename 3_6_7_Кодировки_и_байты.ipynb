# %% [markdown]
# https://stepik.org/lesson/1885001/step/7
#
# 🔗 [GitHub Repository](https://github.com/artemegorof/modules_and_files/blob/main/module_03/lesson_06/step_07/tests)

# %%
longest_word_in_file = lambda f, p='''!"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~''': max(open(f).read().translate(str.maketrans('', '', p)).split()[::-1], key=len)

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_07/english_text.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_07/russian_text.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_07/same_length_words.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_07/punctuation_and_dashes.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_07/edge_case_spaces.txt'

# %%
print(longest_word_in_file('english_text.txt'))
# branches

print(longest_word_in_file('russian_text.txt'))
# Непредсказуемость

print(longest_word_in_file('same_length_words.txt'))
# TypeScript

print(longest_word_in_file('punctuation_and_dashes.txt'))
# testing

print(longest_word_in_file('edge_case_spaces.txt'))
# crystalclear
# Out:
# ['He was running, but it was like running through deep water. \nThere were trees all around him, trees which tried to stop him. \nThey reached out with their branches. And it was behind him. It was coming nearer.', 'He was running, but it was like running through deep water. \nThere were trees all around him, trees which tried to stop him. \nThey reached out with their branches. And it was behind him. It was coming nearer.', 'He was running, but it was like running through deep water. \nThere were trees all around him, trees which tried to stop him. \nThey reached out with their branches. And it was behind him. It was coming nearer.', 'He was running, but it was like running through deep water. \nThere were trees all around him, trees which tried to stop him. \nThey reached out with their branches. And it was behind him. It was coming nearer.', 'He was running, but it was like running through deep water. \nThere were trees all around him, trees which tried to stop him. \nThey reached
# ...

# %%
# longest_word_in_file = lambda f: max([max(xx.strip().split(), key=len) for xx in [x for x in open(f)]], key=len).strip()

# %%
file = open('/content/russian_text.txt', 'r', encoding="utf-8")
content = file.read()  # байты сразу декодируются в строки
# Out:
# 'Он шёл по заснеженному переулку. Вдруг послышался свист — \nэто был ветер, врывающийся между домами. Непредсказуемость происходящего волновала.'

# %%
print("Привет".encode("ascii"))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# /tmp/ipykernel_1558/3883441019.py in <cell line: 0>()
# ----> 1 print("Привет".encode("ascii"))
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 0-5: ordinal not in range(128)
