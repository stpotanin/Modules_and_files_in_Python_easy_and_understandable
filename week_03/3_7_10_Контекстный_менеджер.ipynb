# %% [markdown]
# https://stepik.org/lesson/1612298/step/10

# %%
# @title Вариант с with
def find_lines_len_more_6(file):
    with (open(file) as f): return sum([1 for x in f if len(x.strip()) > 6])

# %%
# # @title Вариант с open
# find_lines_len_more_6 = lambda file: len([x for x in open(file) if len(x.strip()) > 6])

# %%
# @title Вариант с sum
# find_lines_len_more_6 = lambda file: sum(1 for x in open(file) if len(x.strip()) > 6)

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_10/test1.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_10/test2.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_10/test3.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_10/test4.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_10/test1.txt'

# %%
print(find_lines_len_more_6('test1.txt')) # 2
print(find_lines_len_more_6('test2.txt')) # 0
print(find_lines_len_more_6('test3.txt')) # 4
print(find_lines_len_more_6('test4.txt')) # 7
# Out:
# 2
# 0
# 4
# 7
