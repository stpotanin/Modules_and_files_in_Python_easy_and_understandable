# %% [markdown]
# https://stepik.org/lesson/1612298/step/14

# %%
def check_hits(shots_file, ships_file):
    with open (shots_file) as shots, open (ships_file) as ships:
        return len(set([x.strip() for x in shots]) & set([x.strip() for x in ships]))

# %%
# @title Загрузка файлов
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/shots_alpha.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/shots_miss.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/shots_all_hit.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/shots_half_hit.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/shots_case_sensitive.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/shots_mix.txt'

# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/ships_alpha.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/ships_miss.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/ships_all_hit.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/ships_half_hit.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/ships_case_sensitive.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_07/step_14/ships_mix.txt'

# %%
# @title Проверка
print(check_hits('shots_alpha.txt', 'ships_alpha.txt'))                     # 3
print(check_hits('shots_miss.txt', 'ships_miss.txt'))                       # 0
print(check_hits('shots_all_hit.txt', 'ships_all_hit.txt'))                 # 10
print(check_hits('shots_half_hit.txt', 'ships_half_hit.txt'))               # 5
print(check_hits('shots_case_sensitive.txt', 'ships_case_sensitive.txt'))   # 0
print(check_hits('shots_mix.txt', 'ships_mix.txt'))                         # 5
# Out:
# 3
# 0
# 10
# 5
# 0
# 5
