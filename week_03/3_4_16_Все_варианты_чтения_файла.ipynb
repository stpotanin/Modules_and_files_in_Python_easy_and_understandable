# %%
file_n_lines = lambda f, n: [print(line.strip()) for line in list(open(f))[0:n]]
print_first_and_last_line = lambda f: [print(line.strip()) for line in [list(open(f))[i] for i in [0, -1]]]

# %% [markdown]
# 123

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_04/step_16/words.txt'

# %%
file_n_lines('words.txt', 3)
print_first_and_last_line('words.txt')
# Out:
# apple
# banana
# cherry
# apple
# elderberry
# [None, None]

# %%
f = open('words.txt', 'r')
for line in f:
    print(line)
for line in f:
    print(line)
# Out:
# apple
#
# banana
#
# cherry
#
# date
#
# elderberry

# %%
f = open('words.txt', 'r')
for line in f:
    print(line)
f.seek(0)
for line in f:
    print(line)
# Out:
# apple
#
# banana
#
# cherry
#
# date
#
# elderberry
# apple
#
# banana
#
# cherry
#
# date
#
# elderberry

# %%
f = open('words.txt', 'r')
for line in f:
    print(line)
f.close()
file = open('words.txt', 'r')
for record in file:
    print(record)
# Out:
# apple
#
# banana
#
# cherry
#
# date
#
# elderberry
# apple
#
# banana
#
# cherry
#
# date
#
# elderberry
