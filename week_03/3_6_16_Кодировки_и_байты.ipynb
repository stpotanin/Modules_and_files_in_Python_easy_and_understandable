# %% [markdown]
# https://stepik.org/lesson/1885001/step/16

# %%
get_best_student = lambda f: ' '.join(max([x.split() for x in open(f).read().split('\n')][::-1], key=lambda x: int(x[-1]))[:-1][::-1]).replace(':', '')

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_16/top_score_1.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_16/top_score_2.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_16/top_score_3.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_16/top_score_4.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_16/top_score_5.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_06/step_16/top_score_6.txt'

# %%
# @title Чтение файлов
print(get_best_student('top_score_1.txt'))
# Сидор Сидоров

print(get_best_student('top_score_2.txt'))
# Марина Алексеева

print(get_best_student('top_score_3.txt'))
# Людмила Зорина

print(get_best_student('top_score_4.txt'))
# Элвис Пресли

print(get_best_student('top_score_5.txt'))
# Вера Лебедева

print(get_best_student('top_score_6.txt'))
# Ольга Васильева
# Out:
# Сидор Сидоров
# Марина Алексеева
# Людмила Зорина
# Элвис Пресли
# Вера Лебедева
# Ольга Васильева

# %%
# get_best_student = lambda f: [w for w in max([x.split() for x in open(f).read().split('\n')][::-1], key=lambda x: int(x[-1]))]
