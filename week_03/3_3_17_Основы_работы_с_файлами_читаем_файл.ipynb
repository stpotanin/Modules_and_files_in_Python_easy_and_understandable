# %% [markdown]
# https://stepik.org/lesson/1887961/step/17

# %%
with open('heisenberg.txt', 'w') as f:
    f.write('''Say my name.
You're goddamn right.
They all say it, eventually.'''
    )

# %%
with open('capitalization.txt', 'w') as f:
    f.write('''Hello hello HELLO.
hello! Hello?'''
    )

# %%
import string

count_word_in_file = lambda x, w: open(x, 'r').read().lower().count(w.lower())

print(count_word_in_file('heisenberg.txt', "say"))
print(count_word_in_file('capitalization.txt', "hello"))
# Out:
# 2
# 5

# %%
count_word_in_file = lambda z, v: open(z).read().lower().count(v.lower())
print(count_word_in_file('heisenberg.txt', "say"))
print(count_word_in_file('capitalization.txt', "hello"))
# Out:
# 2
# 5
