# %% [markdown]
# https://stepik.org/lesson/1887961/step/16

# %%
with open('heisenberg_1.txt', 'w') as f:
    f.write('''Say my name!
You're goddamn right.'''
    )

# %%
with open('heisenberg_2.txt', 'w') as f:
    f.write('''Say my name!
You're goddamn right.'''
    )

# %%
compare_files = lambda x, y: open(x, 'r').read() == open(y, 'r').read()

print(compare_files('heisenberg_1.txt', 'heisenberg_2.txt'))
# Out:
# True
