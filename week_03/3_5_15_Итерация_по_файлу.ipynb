# %% [markdown]
# https://stepik.org/lesson/1935163/step/15

# %%
sum_columns = lambda f: [sum(col_values) for col_values in zip(*[[int(x) for x in line.strip().split()] for line in open(f)])]

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_15/%D1%81%D0%BC%D0%B5%D1%82%D0%B0_%D1%8F%D0%BD%D0%B2%D0%B0%D1%80%D1%8C.txt'

# %%
print(sum_columns('смета_январь.txt'))
# [3900, 9300, 13800]
# Out:
# [3900, 9300, 13800]
