# %% [markdown]
# https://stepik.org/lesson/1935163/step/12

# %%
most_talkative_line = lambda f: max((list(open(f))[::-1]), key=lambda l: len(l.split()))

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/one_line.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/silence_then_speech.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/equal_length_quotes.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/got_quotes.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/titanic.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/mixed.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/hamlet.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/alphabet_test.txt'
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_05/step_12/mixed_2.txt'

# %%
print(most_talkative_line('one_line.txt'))
# Hello darkness, my old friend

print(most_talkative_line('silence_then_speech.txt'))
# You talkin' to me?

print(most_talkative_line('equal_length_quotes.txt'))
# You shall not pass!

print(most_talkative_line('got_quotes.txt'))
# That's what I do, I drink and I know things.

print(most_talkative_line('titanic.txt'))
# I'm the king of the world!

print(most_talkative_line('mixed.txt'))
# to be or not to be

print(most_talkative_line('hamlet.txt'))
# Whether tis nobler in the mind

print(most_talkative_line('alphabet_test.txt'))
# The quick brown fox jumps over the lazy dog.

print(most_talkative_line('mixed_2.txt'))
# I'm the king of the world!
# Out:
# Hello darkness, my old friend
# You talkin' to me?
#
# You shall not pass!
#
# That's what I do, I drink and I know things.
#
# I'm the king of the world!
#
# to be or not to be
#
# Whether tis nobler in the mind
#
# The quick brown fox jumps over the lazy dog.
#
# I'm the king of the world!
