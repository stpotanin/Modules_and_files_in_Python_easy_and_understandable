# %% [markdown]
# https://stepik.org/lesson/1889714/step/15

# %%
print_first_and_last_line = lambda f: [print(line.strip()) for line in [list(open(f))[i] for i in [0, -1]]]

# %%
# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_04/step_15/chat_alice.txt'

# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_04/step_15/chat_bob.txt'

# !wget -nc -q 'https://raw.githubusercontent.com/artemegorof/modules_and_files/refs/heads/main/module_03/lesson_04/step_15/chat_carla.txt'

# %%
print_first_and_last_line('chat_alice.txt')

# Hello, I need help with my order.
# Thank you, I finally received it!

print_first_and_last_line('chat_bob.txt')

# Is your product compatible with iPhone?
# Is your product compatible with iPhone?

print_first_and_last_line('chat_carla.txt')

# I want to cancel my subscription.
# Thanks for your support.
# Out:
# Hello, I need help with my order.
# Thank you, I finally received it!
# Is your product compatible with iPhone?
# Is your product compatible with iPhone?
# I want to cancel my subscription.
# Thanks for your support.
# [None, None]
